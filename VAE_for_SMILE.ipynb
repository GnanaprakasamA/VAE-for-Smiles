# %% [markdown]
# <a href="https://colab.research.google.com/github/GnanaprakasamA/VAE-for-Smiles/blob/main/VAE_for_SMILE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing_extensions import Concatenate
from ast import Lambda
# Basic Library Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importing necessary Keras library

from tensorflow.keras.layers import Input,Dense,Conv1D,MaxPool1D,Dropout,GRU,\
                                    LSTM,TimeDistributed,Add,Flatten,RepeatVector,Lambda,Concatenate

# %%
data = pd.read_csv("https://raw.githubusercontent.com/GnanaprakasamA/VAE-for-Smiles/main/ESOL%20Solubility.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Compound ID  ESOL predicted log solubility in mols per litre  \
# 0           0   Amigdalin                                           -0.974
# 1           1    Fenfuram                                           -2.885
# 2           2      citral                                           -2.579
# 3           3      Picene                                           -6.618
# 4           4   Thiophene                                           -2.232
#
#    Minimum Degree  Molecular Weight  Number of H-Bond Donors  Number of Rings  \
# 0               1           457.432                        7                3
# 1               1           201.225                        1                2
# 2               1           152.237                        0                0
# 3               2           278.354                        0                5
# 4               2            84.143                        0                1
#
# ...
